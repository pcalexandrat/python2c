# %% [markdown]
# <a href="https://colab.research.google.com/github/pcalexandrat/python2c/blob/main/planilhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Avaliação do Curso - Professores - Técnico em Informática para Internet - Integrado**
# ##Caro professor, você está participando de uma avaliação, cujo objetivo é levantar dados que possam subsidiar melhorias no curso, ao qual ministra aulas. Agradecemos sua colaboração

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQo0uYva9ycvDp0owZ3DAdzLFtucJ7pLFeeVeUOGrbe5WNuc-sFm1tuaf-iTL_Q_q32XGw238mXswy1/pub?gid=2012010921&single=true&output=csv")

# %%
dados
# Out:
#   Carimbo de data/hora  Pontuação  \
# 0                  NaN        NaN
# 1  14/09/2022 11:03:16        NaN
# 2  14/09/2022 11:09:31        NaN
# 3  14/09/2022 11:16:30        NaN
# 4  14/09/2022 14:09:54        NaN
# 5  14/09/2022 15:00:42        NaN
# 6  14/09/2022 15:18:14        NaN
# 7  14/09/2022 15:48:19        NaN
# 8  15/09/2022 08:50:43        NaN
# 9  15/09/2022 10:14:08        NaN
#
#   Estrutura Física da escola - Avalie a estrutura física de sala de aula   \
# 0                                                NaN
# 1                                                Bom
# 2                                          Excelente
# 3                                                Bom
# 4                                          Excelente
# 5                                          Excelente
# 6                                          Excelente
# 7                                                Bom
# 8                                          Excelente
# ...

# %%
dados.hist()
# Out:
# array([[<Axes: title={'center': 'Pontuação'}>,
#         <Axes: title={'center': 'Aprendizagem dos alunos - O interesse dos alunos com a formação ética e cidadã_numeric'}>],
#        [<Axes: title={'center': 'Aprendizagem dos alunos - a assiduidade e pontualidade dos alunos em suas atividades em sala de aula, atendimento e orientações_numeric'}>,
#         <Axes: >]], dtype=object)

# %%
dados["Estrutura Física da escola - Avalie a estrutura física de sala de aula "].hist()
# Out:
# <Axes: >

# %%
dados["Estrutura Física da escola - Avalie a estrutura física de sala de aula "].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - o interesse dos alunos pelos seus estudos, abrangendo a pesquisa e a participação em eventos.'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - as atualizações dos alunos quanto aos conteúdos e bibliografias'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.'].value_counts()
# Out:
# Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.
# Bom             4
# Excelente       3
# Satisfatório    2
# Name: count, dtype: int64

# %%
dados['Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.'].describe()
# Out:
# count       9
# unique      3
# top       Bom
# freq        4
# Name: Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso., dtype: object

# %%
dados.describe()
# Out:
#        Pontuação  \
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
#
#        Aprendizagem dos alunos - O interesse dos alunos com a formação ética e cidadã_numeric  \
# count                                           9.000000
# mean                                            2.555556
# std                                             0.527046
# min                                             2.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        Aprendizagem dos alunos - a assiduidade e pontualidade dos alunos em suas atividades em sala de aula, atendimento e orientações_numeric
# count                                           9.000000
# ...

# %%
dados['Aprendizagem dos alunos - O interesse dos alunos com a formação ética e cidadã'].value_counts()
# Out:
# Aprendizagem dos alunos - O interesse dos alunos com a formação ética e cidadã
# Bom             5
# Satisfatório    4
# Name: count, dtype: int64
